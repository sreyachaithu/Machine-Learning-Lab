# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Car_sales.csv')
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
df.drop_duplicates()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.shape
# Out:
# (157, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
m = df.isnull().sum().idxmax()
df = df.drop(columns=m)
print(f"Dropped column: {m}")
# Out:
# Dropped column: Manufacturer

# %%
#Drop the rows with categorical missing values
s = df.select_dtypes(include='object').columns
df = df.dropna(subset=s)
print(df.shape)
# Out:
# (157, 14)

# %%
df['Price in thousands']=pd.to_numeric(df['Price in thousands'], errors='coerce')
df=df.sort_values(by='Price in thousands',ascending=False)
df
df.iloc[0]
df.iloc[-1]
# Out:
# Model                  Town & Country
# Sales in thousands                 53.48
# 4-year resale value                19.54
# Vehicle type                         Car
# Price in thousands                   NaN
# Engine size                            .
# Horsepower                             .
# Wheelbase                              .
# Width                                  .
# Length                                 .
# Curb weight                            .
# Fuel capacity                          .
# Fuel efficiency                        .
# Latest Launch                  13-Jul-15
# Name: 33, dtype: object

# %%
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
def min_max(column_names):  
    return  df[column_names].min(), df[column_names].max()
print("min and max value:", min_max('Price in thousands'))
# Out:
# min and max value: (9.235, 85.5)

# %%
df['Horsepower']=pd.to_numeric(df['Horsepower'],errors='coerce')
df['Length']=pd.to_numeric(df['Length'], errors='coerce')
df['Fuel capacity']=pd.to_numeric(df['Fuel capacity'], errors='coerce')
def min_max(column_names):
    return df[column_names].min(), df[column_names].max()
print("min and max of:", min_max('Horsepower'))
print("min and max of:", min_max('Length'))
print("min and max of:", min_max('Fuel capacity'))
# Out:
# min and max of: (55.0, 450.0)
# min and max of: (149.4, 224.5)
# min and max of: (10.3, 32.0)

# %%
df["Length"]=pd.to_numeric(df["Length"],errors='coerce')
df=df.dropna(subset="Length")
sns.kdeplot(df["Length"], fill=True)
plt.show()
# Out:
# /home/rgukt-basar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.columns.tolist()
# Out:
# ['Model',
#  'Sales in thousands',
#  '4-year resale value',
#  'Vehicle type',
#  'Price in thousands',
#  'Engine size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb weight',
#  'Fuel capacity',
#  'Fuel efficiency',
#  'Latest Launch']

# %%
df=pd.read_csv('Car_sales.csv')
df
df.columns=df.columns.str.strip()
s=df.groupby('Manufacturer').size().reset_index(name="Count")
print(s)
#df.columns = df.columns.str.strip()
#manufacturer_counts =df.groupby('Manufacturer').size().reset_index(name='Count')
#print(manufacturer_counts)
# Out:
#      Manufacturer  Count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %%
df.columns=df.columns.str.strip()
for col in df.columns:
    df[col]=pd.to_numeric(df[col],errors='coerce')
df=df.select_dtypes(include='number')
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model',
#  'Sales in thousands',
#  '4-year resale value',
#  'Vehicle type',
#  'Price in thousands',
#  'Engine size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb weight',
#  'Fuel capacity',
#  'Fuel efficiency',
#  'Latest Launch']

# %%
df.columns=df.columns.str.strip()
for col in df.columns:
    df[col]=pd.to_numeric(df[col],errors='coerce')
s=df.select_dtypes(include='number')
s.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model',
#  'Sales in thousands',
#  '4-year resale value',
#  'Vehicle type',
#  'Price in thousands',
#  'Engine size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb weight',
#  'Fuel capacity',
#  'Fuel efficiency',
#  'Latest Launch']

# %%
df=df['Price in thousands'].corr(df['Sales in thousands'])
df
# Out:
# -0.3047344541294122

# %%
df=pd.read_csv('Car_sales.csv')
df
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
sns.lmplot(x='Price in thousands', y='Sales in thousands', data=df)
plt.show()

# %%
sns.pairplot(df)
# Out:
# /home/rgukt-basar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/rgukt-basar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x='Price in thousands',y='Sales in thousands', data=df)
# Out:
# <Axes: xlabel='Price in thousands', ylabel='Sales in thousands'>

# %%
for col in df.select_dtypes(include='number').columns:
    sns.boxplot(x='Manufacturer', y=col,data=df)
    plt.title(f"{col} distribution")
    plt.show()

# %%
pd.get_dummies(df,columns=['Vehicle type'],drop_first=True)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
cols=df.select_dtypes(include='object').columns
for i in cols:
    df[i]=le.fit_transform(df[i].astype(str))
print(df.isnull().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     2
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
df
# Out:
#      Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0               0     79              16.919                   53
# 1               0    143              39.384                   70
# 2               0     25              14.114                   63
# 3               0    115               8.588                   87
# 4               1      8              20.397                   78
# ..            ...    ...                 ...                  ...
# 152            29    148               3.545                    0
# 153            29    125              15.245                    0
# 154            29    149              17.531                    0
# 155            29     24               3.493                    0
# 156            29    126              18.969                    0
#
#      Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0               1               21.50            4          17          5
# ...

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns=['Price in thousands'])
y=df['Price in thousands']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Load the data
df = pd.read_csv("Car_sales.csv")

# Columns to scale
columns = ["Price in thousands", "Sales in thousands", "Horsepower", "Fuel efficiency"]

# Convert to numeric and handle errors by coercing non-numeric values to NaN
df[columns] = df[columns].apply(pd.to_numeric, errors='coerce')

# Drop rows with missing values
df_cleaned = df.dropna(subset=columns)

# Apply Min-Max Scaling (Normalization)
def min_max_scale(column):
    X_min = column.min()
    X_max = column.max()
    return (column - X_min) / (X_max - X_min)

# Create a copy for normalized data
df_normalized = df_cleaned.copy()
df_normalized[columns] = df_cleaned[columns].apply(min_max_scale)

# Display normalized data
print("Normalized Data:")
print(df_normalized[columns].head())

# Apply Standardization (Z-score Normalization)
def standardize(column):
    mean = column.mean()
    std_dev = column.std()
    return (column - mean) / std_dev

# Create a copy for standardized data
df_standardized = df_cleaned.copy()
df_standardized[columns] = df_cleaned[columns].apply(standardize)

# Display standardized data
print("Standardized Data:")
print(df_standardized[columns].head())
# Out:
# Normalized Data:
#    Price in thousands  Sales in thousands  Horsepower  Fuel efficiency
# 0            0.160821            0.031102    0.215190         0.433333
# 1            0.251295            0.072669    0.430380         0.333333
# 3            0.429620            0.015687    0.392405         0.233333
# 4            0.193470            0.037537    0.240506         0.400000
# 5            0.324067            0.034545    0.367089         0.233333
# Standardized Data:
#    Price in thousands  Sales in thousands  Horsepower  Fuel efficiency
# 0           -0.411687           -0.526268   -0.795027         0.971291
# 1            0.066224           -0.199636    0.693502         0.272510
# 3            1.008193           -0.647397    0.430821        -0.426272
# 4           -0.239223           -0.475699   -0.619906         0.738364
# 5            0.450631           -0.499209    0.255700        -0.426272

# %%
# Assuming x_train and x_test are already NumPy arrays
x_train = x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)

from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Initialize the scalers
scaler = StandardScaler()   # for Standardization
normalizer = MinMaxScaler() # for Min-Max Scaling

# Apply Standardization (Z-score Normalization)
x_train_standardized = scaler.fit_transform(x_train)
x_test_standardized = scaler.transform(x_test)

# Apply Min-Max Normalization
x_train_normalized = normalizer.fit_transform(x_train)
x_test_normalized = normalizer.transform(x_test)

# Display the results
print("Standardized x_train:")
print(x_train_standardized[:5])  # Show first 5 rows
print("\nNormalized x_train:")
print(x_train_normalized[:5])  # Show first 5 rows
# Out:
# Standardized x_train:
# [[-0.31047972]
#  [ 1.6570827 ]
#  [ 0.25770312]
#  [ 0.37816713]
#  [-0.97453204]]
#
# Normalized x_train:
# [[0.05179804]
#  [0.19979244]
#  [0.09453512]
#  [0.10359608]
#  [0.00184993]]

# %%
x_train=x_train.reshape(-1, 1)
x_test=x_test.reshape(-1, 1)
scaler=StandardScaler()
normalizer=MinMaxScaler()
x_train_s=scaler.fit_transform(x_train)
x_test_s=scaler.transform(x_test)
x_train_n=normalizer.fit_transform(x_train)
x_test_n=normalizer.transform(x_test)
print("scaler:")
print(x_train_s[ :5])
print("normalizer:")
print(x_train_n[ :5])
# Out:
# scaler:
# [[-0.31047972]
#  [ 1.6570827 ]
#  [ 0.25770312]
#  [ 0.37816713]
#  [-0.97453204]]
# normalizer:
# [[0.05179804]
#  [0.19979244]
#  [0.09453512]
#  [0.10359608]
#  [0.00184993]]

# %%
x_train=x_train.reshape(-1, 1)
x_test=x_tets.reshape(-1, 1)
scaler=StandardScaler()
normalizer=normalizer()
x_train_s=scaler.fit_transform(x_train)
x_test_s=scaler.fit_transform(x_test)
x_train_n=scaler
