# %%
#1 1. Read top five values
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#2 Print dataframe info_data types of each column
df.head
# Out:
# <bound method NDFrame.head of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#3 Print number of rows and columns
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
#4 Drop duplicate rows_if any
df.shape
# Out:
# (157, 15)

# %%
#5 Print number of rows and columns after dropping duplicates
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# ...

# %%
 # 6.Print number of rows and columns
df.shape
# Out:
# (157, 15)

# %%
#7 Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
#8
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
#9 Print number of missing values in each column
mis=df.isnull().sum().idxmax()
df.drop(columns=[mis],inplace=True)
df.shape
# Out:
# (157, 14)

# %%
#10 Import the rows with numerical missing values
cat=df.select_dtypes(include="object").columns
df.dropna(subset=cat,inplace=True)
df.shape
# Out:
# (157, 14)

# %%
#10 Import the rows with numerical missing values
nume=df.select_dtypes(include="number").columns
df[nume]=df[nume].fillna(df[nume].mean())
df[nume]
# Out:
#      Sales in thousands
# 0                16.919
# 1                39.384
# 2                14.114
# 3                 8.588
# 4                20.397
# ..                  ...
# 152               3.545
# 153              15.245
# 154              17.531
# 155               3.493
# 156              18.969
#
# [157 rows x 1 columns]

# %%
#12
numcols=df.select_dtypes(include='number').columns
df[numcols]=df[numcols].fillna(df[numcols].mean())
df[numcols]
# Out:
#      Sales in thousands
# 0                16.919
# 1                39.384
# 2                14.114
# 3                 8.588
# 4                20.397
# ..                  ...
# 152               3.545
# 153              15.245
# 154              17.531
# 155               3.493
# 156              18.969
#
# [157 rows x 1 columns]

# %%
#13 Sort the data w.r.t price_find the details of the most
and the least expensive cars
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors="coerce")
df=df.sort_values(by=['Price in thousands'],ascending=False)
df
print(df.iloc[0])
print(df.iloc[-1])
# Out:
# Model                  CL500
# Sales in thousands                 0.954
# 4-year resale value                    .
# Vehicle type                   Passenger
# Price in thousands                  85.5
# Engine size                            5
# Horsepower                           302
# Wheelbase                          113.6
# Width                               73.1
# Length                             196.6
# Curb weight                        4.115
# Fuel capacity                       23.2
# Fuel efficiency                       20
# Latest Launch                   4-Nov-15
# Name: 99, dtype: object
# Model                  Town & Country
# Sales in thousands                 53.48
# 4-year resale value                19.54
# Vehicle type                         Car
# Price in thousands                   NaN
# Engine size                            .
# Horsepower                             .
# Wheelbase                              .
# Width                                  .
# ...

# %%
#13. Call the above function to find min max of horse power, length, fuel efficiency

price,sales,hoursepower,fuelefficiency
df['Horsepower']=pd.to_numeric(df['Horsepower'],errors='coerce')
df['Length']=pd.to_numeric(df['Length'],errors='coerce')
df['Fuel efficiency']=pd.to_numeric(df['Fuel efficiency'],errors='coerce')
def min_max(column_name):
     return df[column_name].min(),df[column_name].max()
print("max horsepower:", min_max('Horsepower'))  
print("max langth:", min_max('Length'))
print("max Fuel efficiency:", min_max('Fuel efficiency'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #13. Call the above function to find min max of horse power, length, fuel efficiency
# ----> 3 price,sales,hoursepower,fuelefficiency
#       4 df['Horsepower']=pd.to_numeric(df['Horsepower'],errors='coerce')
#       5 df['Length']=pd.to_numeric(df['Length'],errors='coerce')
#
# NameError: name 'price' is not defined

# %%
#14.Plot histogram of continuous numerical variable :
continues=df[['Price in thousands','Sales in thousands','Horsepower','Fuel efficiency']]
sns.histplot(continues)
plt.show()

# %%
#15. Probability density distribution of continuous
numerical variable-length
df["Length"]=pd.to_numeric(df["Length"],errors="coerce")
df=df.dropna(subset=["Length"])
sns.kdeplot(df["Length"],fill=True)
plt.xlabel("length")
plt.ylabel("density")
plt.show()
# Out:
#   Cell In[15], line 2
#     numerical variable-length
#               ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("Car_sales.csv")
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#16
# Remove leading/trailing spaces from column names
df.columns = df.columns.str.strip()
manufacturer_counts =df.groupby('Manufacturer').size().reset_index(name='Count')
print(manufacturer_counts)

#manufacturer_counts=df.groupby('Manufacturer').size().reset_index(name='Count')
manufacturer_counts 
#17
df['Price in thousands'] = pd.to_numeric(df['Price in thousands'], errors='coerce')
df['Sales in thousands'] = pd.to_numeric(df['Sales in thousands'], errors='coerce')
numerical=df.select_dtypes(include="number")
print(numerical)
#18
correlation_co=df['Price in thousands'].corr(df['Sales in thousands'])
print("relation:{correlation:.4f}")
#19
sns.lmplot(x='Price in thousands',y='Sales in thousands',data=df)
#20
sns.pairplot(df)
# Out:
#      Manufacturer  Count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6
#      Sales in thousands  Price in thousands
# 0                16.919               21.50
# 1                39.384               28.40
# ...

# %%
#21
sns.boxplot(x="Price in thousands",y="Sales in thousands",data=df)
plt.show()

# %%
#22
for col in df.select_dtypes(include=['number']).columns:
     sns.boxplot(x='Manufacturer',y=col,data=df)
     plt.show()

# %%
#23
y=df['Sales in thousands']
x=df.drop(columns=["Sales in thousands"])
print(x)
print(y)
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 0    Acura          Integra                         16.36    Passenger
# 1    Acura          TL                             19.875    Passenger
# 2    Acura          CL                             18.225    Passenger
# 3    Acura          RL                             29.725    Passenger
# 4    Audi           A4                             22.255    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                                 .    Passenger
# 153  Volvo          S70                                 .    Passenger
# 154  Volvo          V70                                 .    Passenger
# 155  Volvo          C70                                 .    Passenger
# 156  Volvo          S80                                 .    Passenger
#
#      Price in thousands Engine size Horsepower Wheelbase Width Length  \
# ...

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=['Price in thousands'])
y=df['Price in thousands']
print(X)
print(y)
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
#26.Split the data set into train and test set 70% train set
10% test set
from sklearn.model_selection import train_test_split
X=df.drop(columns=['Price in thousands'])
y=df['Price in thousands']
print(X)
print(y)
X_train,y_train,X_test,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
# Out:
#   Cell In[22], line 2
#     10% test set
#              ^
# SyntaxError: invalid syntax

# %%
nume=pd.to_numeric(df['Price in thousands'],errors='coerce')
nume

# %%
X=df.drop(columns=['Price in thousands'])
y=df['Price in thousands']

# %%
from sklearn.preprocessing import LabelEncoder
model=LabelEncoder()
model

# %%
#25
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
cat_col=df.select_dtypes(include=['object']).columns
le=LabelEncoder()
for col in cat_col:
  df[col]=le.fit_transform(df[col].astype(str))
print(cat_col,df.head())

# %%
#25
df=pd.get_dummies(df,columns=['Vehicle type'],prefix="vehicle", drop_first=True)
print(df.head())

# %%
num=df.select_dtypes(include="number").columns

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Load the dataset
file_path = 'Car_sales.csv'  # Adjust path if needed
df = pd.read_csv(file_path)

# List of numerical columns to scale
numeric_columns = [
    'Sales in thousands', '4-year resale value', 'Price in thousands',
    'Engine size', 'Horsepower', 'Wheelbase', 'Width',
    'Length', 'Curb weight', 'Fuel capacity', 'Fuel efficiency'
]

# Convert columns to numeric (coerce errors to NaN for invalid entries)
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Drop rows with missing values in numeric columns
df_numeric = df[numeric_columns].dropna()

# Apply Standardization (Z-score)
standard_scaler = StandardScaler()
df_standard_scaled = pd.DataFrame(standard_scaler.fit_transform(df_numeric), columns=numeric_columns)

# Apply Min-Max Normalization
minmax_scaler = MinMaxScaler()
df_minmax_scaled = pd.DataFrame(minmax_scaler.fit_transform(df_numeric), columns=numeric_columns)

# Save scaled data to CSV files (optional)
df_standard_scaled.to_csv('Car_sales_standardized.csv', index=False)
df_minmax_scaled.to_csv('Car_sales_minmax_scaled.csv', index=False)

# Display first few rows
print("Standardized Data:\n", df_standard_scaled.head())
print("\nMin-Max Normalized Data:\n", df_minmax_scaled.head())

# %%
#27Apply feature scaling on numerical variables
num=df.select_dtypes(include="number").columns
for i in num:
    std=df[i].std()
    mean=df[i].mean()
    df[i]=(df[i]-mean)/std
    print(df[i].head())   
for j in num:
    min=df[j].min()
    max=df[j].max()
    df[j]=(df[j]-max)/(max-min)
    print(df[j].head())
# Out:
# 0   -1.688817
# 1   -1.688817
# 2   -1.688817
# 3   -1.688817
# 4   -1.572474
# Name: Manufacturer, dtype: float64
# 0    0.029529
# 1    1.449163
# 2   -1.168288
# 3    0.828073
# 4   -1.545378
# Name: Model, dtype: float64
# 0   -0.530345
# 1   -0.200120
# 2   -0.571577
# 3   -0.652807
# 4   -0.479220
# Name: Sales in thousands, dtype: float64
# 0    0.194092
# 1    0.633102
# 2    0.452333
# 3    1.072112
# 4    0.839695
# Name: 4-year resale value, dtype: float64
# 0   -0.410458
# 1    0.070323
# 2         NaN
# 3    1.017949
# 4   -0.236959
# Name: Price in thousands, dtype: float64
# 0   -1.352119
# 1    0.276648
# 2    0.276648
# 3    0.683840
# 4   -1.352119
# Name: Engine size, dtype: float64
# 0   -0.964517
# 1    0.948639
# 2    0.948639
# 3    0.600792
# 4   -0.674645
# Name: Horsepower, dtype: float64
# 0   -1.537680
# 1   -0.229537
# 2   -0.524924
# 3    0.614427
# 4   -1.368887
# Name: Wheelbase, dtype: float64
# 0   -1.242617
# 1   -0.191037
# 2   -0.053875
# ...

# %%
num=df.select_dtypes(include="number").columns
for i in num:
    std=df[i].std()
    mean=df[i].mean()
    df[i]=(df[i]-mean)/std
    print(df[i].head())   
for j in num:
    min=df[j].min()
    max=df[j].max()
    df[j]=(df[j]-max)/(max-min)
    print(df[j].head())
# Out:
# 0   -0.530345
# 1   -0.200120
# 2   -0.571577
# 3   -0.652807
# 4   -0.479220
# Name: Sales in thousands, dtype: float64
# 0   -0.149561
# 1    0.157336
# 2    0.013273
# 3    1.017343
# 4    0.365134
# Name: 4-year resale value, dtype: float64
# 0   -0.410458
# 1    0.070323
# 2         NaN
# 3    1.017949
# 4   -0.236959
# Name: Price in thousands, dtype: float64
# 0   -1.207001
# 1    0.133157
# 2    0.133157
# 3    0.420333
# 4   -1.207001
# Name: Engine size, dtype: float64
# 0   -0.810378
# 1    0.688731
# 2    0.688731
# 3    0.424182
# 4   -0.634013
# Name: Horsepower, dtype: float64
# 0   -0.822789
# 1    0.080198
# 2   -0.076843
# 3    0.930839
# 4   -0.639574
# Name: Wheelbase, dtype: float64
# 0   -1.115337
# 1   -0.246243
# 2   -0.159334
# 3    0.072424
# 4   -0.854609
# Name: Width, dtype: float64
# 0   -1.112557
# 1    0.413677
# 2    0.346672
# 3    0.689144
# 4   -0.695634
# Name: Length, dtype: float64
# 0   -1.172124
# 1    0.220418
# 2    0.145875
# 3    0.748569
# ...

# %%
numerical_df = df.select_dtypes(include=['number'])
print(numerical_df.columns)
# Out:
# Index(['Sales in thousands', '4-year resale value', 'Price in thousands',
#        'Engine size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb weight', 'Fuel capacity', 'Fuel efficiency'],
#       dtype='object')

# %%
#25. Encode categorical variable vehicle type using one-hot encoder
from sklearn.preprocessing import OneHotEncoder
