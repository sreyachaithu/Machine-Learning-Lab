# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('tvmarketing.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
x=df['TV']
y=df['Sales']

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x=x,y=y)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.3)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (140,) (60,) (140,) (60,)

# %%
y_pred=slope*x_mean+intercept
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 y_pred=slope*x_mean+intercept
#       2 y_pred
#
# NameError: name 'slope' is not defined

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le
# Out:
# LinearRegression()

# %%
# If x_train and y_train are pandas Series (e.g., from a DataFrame column)

# Convert to lists to avoid .iloc or label-based indexing issues
x_train = x_train.tolist()
y_train = y_train.tolist()

# Calculate means
x_mean = sum(x_train) / len(x_train)
y_mean = sum(y_train) / len(y_train)

# Initialize numerator and denominator
num = 0
den = 0

# Loop for least squares calculation
for i in range(len(x_train)):
    num += (x_train[i] - x_mean) * (y_train[i] - y_mean)
    den += (x_train[i] - x_mean) ** 2

# Calculate slope and intercept
slope = num / den
intercept = y_mean - slope * x_mean

# Print result
print(f"Final output: y = {slope:.4f}x + {intercept:.4f}")
# Out:
# Final output: y = 0.0452x + 7.1428

# %%
#x_train = x_train.tolist()
#y_train = y_train.tolist()

x_mean = sum(x_train) / len(x_train)
y_mean = sum(y_train) / len(y_train)

num = 0
den = 0
for i in range(len(x_train)):
    num += (x_train[i] - x_mean) * (y_train[i] - y_mean)
    den += (x_train[i] - x_mean) ** 2

slope = num / den
intercept = y_mean - slope * x_mean

print(f"Output: y = {slope:.4f}x + {intercept:.4f}")

# %%
y_pred=slope*x_mean+intercept
y_pred

# %%
from sklearn.linear_model import LinearRegression
li=LinearRegression()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Assuming x_train, x_test, y_train are all Python lists
x_train_reshape = np.array(x_train).reshape(-1, 1)
x_test_reshape = np.array(x_test).reshape(-1, 1)
li.fit(x_train_reshape, y_train)

print("Intercept:", li.intercept_)
print("Coefficient:", li.coef_[0])
# Out:
# Intercept: 7.142783780024919
# Coefficient: 0.04523417413842785

# %%
plt.scatter(x_train_reshape,y_train)
plt.plot(x_train_reshape, li.predict(x_train_reshape),color="red")

# %%
plt.scatter(x_test_reshape,y_test)
plt.plot(x_test_reshape,li.predict(x_test_reshape),color="red")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

x_train_reshape=np.array(x_train).reshape(-1, 1)

x_test_reshape=np.array(x_test).reshape(-1, 1)

# %%
li=LinearRegression()

# %%
li.fit(x_train_reshape,y_train)
# Out:
# LinearRegression()

# %%
y_pred=li.predict(x_test_reshape)
y_pred
# Out:
# array([16.79575654, 19.87168038, 12.61611885, 16.37507872, 17.41998814,
#        15.90464331, 11.13696136, 20.15213226,  7.38704832,  7.98866284,
#        10.52177659, 15.50658258, 20.42353731, 19.52337724, 13.48913841,
#        17.45617548, 15.09042818,  7.99318625, 18.39704631, 12.71111062,
#        16.30270404, 16.13986102, 16.14890785,  9.09237669, 20.2923582 ,
#        15.40254398, 17.98993874,  8.56766027, 11.0193525 , 18.14373493,
#        15.6422851 ,  9.08785327, 15.50658258,  9.96087283, 12.57993151,
#        13.60674726, 12.38994798, 10.20966079, 13.80577763,  7.1744477 ,
#        16.93145906, 11.78833346,  8.8616824 , 19.81739937,  7.73987488,
#        14.52952442, 11.23195312, 10.33631647, 17.88137672, 14.22645545,
#        14.68784403,  7.32824389, 14.58380543, 13.53437259, 12.99608591,
#        11.47169425, 12.1094961 , 14.89139781, 18.00350899, 17.55116725])

# %%
mse=mean_squared_error(y_test, y_pred)

# %%
rv=r2_score(y_test,y_pred)

# %%
print(mse)
print(rv)
# Out:
# 11.217072098533675
# 0.6210875318590132

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('set2_data.csv')
df
# Out:
#      buying  maint  doors persons lug_boot safety car_acceptability
# 0     vhigh  vhigh      2       2    small    low             unacc
# 1     vhigh  vhigh      2       2    small    med             unacc
# 2     vhigh  vhigh      2       2    small   high             unacc
# 3       NaN  vhigh      2       2      med    low             unacc
# 4     vhigh    NaN      2       2      med    med             unacc
# ...     ...    ...    ...     ...      ...    ...               ...
# 1723    low    low  5more    more      med    med              good
# 1724    low    low  5more    more      med   high             vgood
# 1725    low    low  5more    more      big    low             unacc
# 1726    low    low  5more    more      big    med              good
# 1727    low    low  5more    more      big   high             vgood
#
# [1728 rows x 7 columns]

# %%
print(df.head())
# Out:
#   buying  maint doors persons lug_boot safety car_acceptability
# 0  vhigh  vhigh     2       2    small    low             unacc
# 1  vhigh  vhigh     2       2    small    med             unacc
# 2  vhigh  vhigh     2       2    small   high             unacc
# 3    NaN  vhigh     2       2      med    low             unacc
# 4  vhigh    NaN     2       2      med    med             unacc

# %%
print(df.sample(5,random_state=1))
# Out:
#      buying maint  doors persons lug_boot safety car_acceptability
# 1233    med   low      3    more    small    low             unacc
# 592    high  high      3    more      big    med               acc
# 625    high  high  5more       2      med    med             unacc
# 1546    low   med      3       2      big    med             unacc
# 730    high   med  5more       2    small    med             unacc

# %%
df.isnull().sum()
# Out:
# buying               1
# maint                2
# doors                0
# persons              1
# lug_boot             1
# safety               1
# car_acceptability    0
# dtype: int64

# %%
df.describe()
# Out:
#        buying maint doors persons lug_boot safety car_acceptability
# count    1727  1726  1728    1727     1727   1727              1728
# unique      4     4     4       3        3      3                 4
# top      high  high     2       2      med    low             unacc
# freq      432   432   432     576      576    576              1210

# %%
df.shape
# Out:
# (1728, 7)

# %%
for col in df.columns:
    if df[col].dtype == 'object':
      mode_val=df[col].mode()[0]
      df[col].fillna(mode_val, inplace=True)
    else: 
      mean_val=df[col].mean()
      df[col].fillna(mean_val, inplace=True)
print(df.isnull().sum())
# Out:
# buying               0
# maint                0
# doors                0
# persons              0
# lug_boot             0
# safety               0
# car_acceptability    0
# dtype: int64

# %%
df.count()
# Out:
# buying               1728
# maint                1728
# doors                1728
# persons              1728
# lug_boot             1728
# safety               1728
# car_acceptability    1728
# dtype: int64

# %%
    plt.hist(data=df,x='doors')
    plt.show()

# %%
cols=['buying', 'maint', 'lug_boot', 'safety']
fig,axes=plt.subplots(1, 4, figsize=(16, 4))
for i,col in enumerate(cols):
    axes[i].bar(df[col].value_counts().index, df[col].value_counts().values)
    axes[i].set_title(f'{col} distribution')
plt.tight_layout()
plt.show()

# %%
df['doors']=df['doors'].replace({'5more':'5', 'more':'5'})
df
# Out:
#      buying  maint doors persons lug_boot safety car_acceptability
# 0     vhigh  vhigh     2       2    small    low             unacc
# 1     vhigh  vhigh     2       2    small    med             unacc
# 2     vhigh  vhigh     2       2    small   high             unacc
# 3      high  vhigh     2       2      med    low             unacc
# 4     vhigh   high     2       2      med    med             unacc
# ...     ...    ...   ...     ...      ...    ...               ...
# 1723    low    low     5    more      med    med              good
# 1724    low    low     5    more      med   high             vgood
# 1725    low    low     5    more      big    low             unacc
# 1726    low    low     5    more      big    med              good
# 1727    low    low     5    more      big   high             vgood
#
# [1728 rows x 7 columns]

# %%
df['car_acceptability'].value_counts().plot.pie(autopct='%1.1f%%', title='Distribution')
# Out:
# <Axes: title={'center': 'Distribution'}, ylabel='count'>

# %%
x=df.drop(columns=['car_acceptability'])
y=df['car_acceptability']

# %%
df['persons']=df['persons'].replace({'more':'5'})
df
# Out:
#      buying  maint doors persons lug_boot safety car_acceptability
# 0     vhigh  vhigh     2       2    small    low             unacc
# 1     vhigh  vhigh     2       2    small    med             unacc
# 2     vhigh  vhigh     2       2    small   high             unacc
# 3      high  vhigh     2       2      med    low             unacc
# 4     vhigh   high     2       2      med    med             unacc
# ...     ...    ...   ...     ...      ...    ...               ...
# 1723    low    low     5       5      med    med              good
# 1724    low    low     5       5      med   high             vgood
# 1725    low    low     5       5      big    low             unacc
# 1726    low    low     5       5      big    med              good
# 1727    low    low     5       5      big   high             vgood
#
# [1728 rows x 7 columns]

# %%
df
# Out:
#      buying  maint doors persons lug_boot safety car_acceptability
# 0     vhigh  vhigh     2       2    small    low             unacc
# 1     vhigh  vhigh     2       2    small    med             unacc
# 2     vhigh  vhigh     2       2    small   high             unacc
# 3      high  vhigh     2       2      med    low             unacc
# 4     vhigh   high     2       2      med    med             unacc
# ...     ...    ...   ...     ...      ...    ...               ...
# 1723    low    low     5       5      med    med              good
# 1724    low    low     5       5      med   high             vgood
# 1725    low    low     5       5      big    low             unacc
# 1726    low    low     5       5      big    med              good
# 1727    low    low     5       5      big   high             vgood
#
# [1728 rows x 7 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
le=LogisticRegression()
le.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10223/1502407912.py in ?()
#       1 from sklearn.linear_model import LogisticRegression
#       2 le=LogisticRegression()
# ----> 3 le.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
#    1192             _dtype = np.float64
#    1193         else:
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#    1199             accept_sparse="csr",
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     580                 if "estimator" not in check_y_params:
#     581                     check_y_params = {**default_check_params, **check_y_params}
# ...

# %%
y_pred=le.predict(x_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10223/1699189033.py in ?()
# ----> 1 y_pred=le.predict(x_test)
#       2 y_pred
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_base.py in ?(self, X)
#     415         y_pred : ndarray of shape (n_samples,)
#     416             Vector containing the class labels for each sample.
#     417         """
#     418         xp, _ = get_namespace(X)
# --> 419         scores = self.decision_function(X)
#     420         if len(scores.shape) == 1:
#     421             indices = xp.astype(scores > 0, int)
#     422         else:
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_base.py in ?(self, X)
#     396         """
#     397         check_is_fitted(self)
#     398         xp, _ = get_namespace(X)
#     399
# ...
